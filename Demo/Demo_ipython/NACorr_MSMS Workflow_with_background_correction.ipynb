# %% [markdown]
# ## **Ipthon Script to calculate NACorrection and Fractional Enrichment for a demo dataset.**
#
# Prerequisite Knowledge:
#
# **Natural Abundance Correction**- Natural abundance (NA) refers to the abundance of isotopes of a chemical element as naturally found on the planet. While performing analysis,the observed intensity contains contribution from isotopic natural abundance that needs to be corrected. This process is referred as NA Correction.
#
# **Pool Total**- Sum of the intensities of all different number of labeled atoms of the isotope element is called pool total.
#
# **Fractional enrichment**- Normalization of intensities of a metabolite between the range of 0 to 1.

# %% [markdown]
# **Welcome to the interactive Polly IPython Notebook.**
#
# With this interactive Polly notebook you would be able to calculate NA Corrected intensities as well as fractional enrichment for LCMS/MS input file. Information on some functions used:
#
#  - corna- package which looks into NA Correction.
#  - msms.csv - demo raw_intensity file.
#  - multiquant_parser.merge_mq_metadata - merge multiquant files and metadata files
#  - multiquant_parser.add_mass_and_no_of_atoms_info_frm_label - from label column add information of molecular mass,    isotopic mass, total number of atoms, number of labeled atoms for parent as well as isotope fragment.
#  - fractional_enrichment - Calculates fractional enrichment for the NA Corrected dataframe.

# %%
import pandas as pd
import numpy as np
import re

import corna.constants as const
from corna.helpers import get_isotope_na, replace_negatives_in_column
from corna.inputs.column_conventions import multiquant 
from corna.inputs import multiquant_parser
from corna.postprocess import fractional_enrichment
from corna.algorithms.background_correction import background_correction

# %% [markdown]
# **Defining the input files path and Natural Abundance values of elements.**

# %%
raw_df= pd.read_csv('raw_intensity_file.csv')
metadata_df= pd.read_excel('metadata.xlsx')
sample_metadata = pd.read_excel('metadata_sample.xlsx')
isBackground= False
isotope_dict= const.ISOTOPE_NA_MASS
REQUIRED_COL= [multiquant.FORMULA, multiquant.LABEL, multiquant.NAME, multiquant.SAMPLE, multiquant.COHORT,
                     multiquant.MQ_FRAGMENT, multiquant.INTENSITY, multiquant.PARENT_FORM,const.NA_CORRECTED_COL, 
                        const.BACKGROUND_WITH_ZERO, const.BACKGROUND_CORRECTED]

# %% [markdown]
# **Merge the raw_intensity dataframe with the metadata and sample metadata(if background correction to be performed).**

# %%
msms_df, list_of_replicates = multiquant_parser.merge_mq_metadata(raw_df, metadata_df, sample_metadata)
# Out:
# /home/priyanka/corna_package/env_corna/local/lib/python2.7/site-packages/corna-0.0.328-py2.7.egg/corna/inputs/multiquant_parser.py:187: UserWarning: Std samples not found inCohort Name column
#   warnings.warn('Std samples not found in' + multiquant.COHORT + ' column')

# %%
final_df = background_correction(msms_df, list_of_replicates, isotope_dict=const.ISOTOPE_NA_MASS)
final_df = replace_negatives_in_column(final_df,const.BACKGROUND_WITH_ZERO, const.BACKGROUND_CORRECTED)
print final_df
# Out:
# /home/priyanka/corna_package/env_corna/local/lib/python2.7/site-packages/pandas/core/indexing.py:297: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/priyanka/corna_package/env_corna/local/lib/python2.7/site-packages/pandas/core/indexing.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#                               Sample                  Cohort Name  \
# 0     Filename_ABC.wiff (sample 426)    A. [13C-glc] Cohort1 0min
# 48    Filename_ABC.wiff (sample 427)    B. [13C-glc] Cohort1 5min
# 96    Filename_ABC.wiff (sample 428)   C. [13C-glc] Cohort1 15min
# 144   Filename_ABC.wiff (sample 429)   D. [13C-glc] Cohort1 30min
# 192   Filename_ABC.wiff (sample 430)   E. [13C-glc] Cohort1 60min
# 240   Filename_ABC.wiff (sample 431)  F. [13C-glc] Cohort1 120min
# 288   Filename_ABC.wiff (sample 432)  G. [13C-glc] Cohort1 240min
# 336   Filename_ABC.wiff (sample 434)    I. [13C-glc] Cohort2 0min
# 384   Filename_ABC.wiff (sample 435)    J. [13C-glc] Cohort2 5min
# 432   Filename_ABC.wiff (sample 436)   K. [13C-glc] Cohort2 15min
# 480   Filename_ABC.wiff (sample 437)   L. [13C-glc] Cohort2 30min
# 528   Filename_ABC.wiff (sample 438)   M. [13C-glc] Cohort2 60min
# 576   Filename_ABC.wiff (sample 439)  N. [13C-glc] Cohort2 120min
# 624   Filename_ABC.wiff (sample 440)  O. [13C-glc] Cohort2 240min
# 672   Filename_ABC.wiff (sample 442)    Q. [13C-glc] Cohort3 0min
# 720   Filename_ABC.wiff (sample 443)    R. [13C-glc] Cohort3 5min
# 768   Filename_ABC.wiff (sample 444)   S. [13C-glc] Cohort3 15min
# 816   Filename_ABC.wiff (sample 445)   T. [13C-glc] Cohort3 30min
# 864   Filename_ABC.wiff (sample 446)   U. [13C-glc] Cohort3 60min
# 912   Filename_ABC.wiff (sample 447)  V. [13C-glc] Cohort3 120min
# 960   Filename_ABC.wiff (sample 448)  W. [13C-glc] Cohort3 240min
# 1008  Filename_ABC.wiff (sample 450)    A. [13C-glc] Cohort1 0min
# 1056  Filename_ABC.wiff (sample 451)    B. [13C-glc] Cohort1 5min
# 1104  Filename_ABC.wiff (sample 452)   C. [13C-glc] Cohort1 15min
# 1152  Filename_ABC.wiff (sample 453)   D. [13C-glc] Cohort1 30min
# 1200  Filename_ABC.wiff (sample 454)   E. [13C-glc] Cohort1 60min
# 1248  Filename_ABC.wiff (sample 455)  F. [13C-glc] Cohort1 120min
# 1296  Filename_ABC.wiff (sample 456)  G. [13C-glc] Cohort1 240min
# 1344  Filename_ABC.wiff (sample 458)    I. [13C-glc] Cohort2 0min
# 1392  Filename_ABC.wiff (sample 459)    J. [13C-glc] Cohort2 5min
# ...                              ...                          ...
# 4655  Filename_ABC.wiff (sample 535)  N. [13C-glc] Cohort2 120min
# 4703  Filename_ABC.wiff (sample 536)  O. [13C-glc] Cohort2 240min
# 4751  Filename_ABC.wiff (sample 538)    Q. [13C-glc] Cohort3 0min
# 4799  Filename_ABC.wiff (sample 539)    R. [13C-glc] Cohort3 5min
# 4847  Filename_ABC.wiff (sample 540)   S. [13C-glc] Cohort3 15min
# 4895  Filename_ABC.wiff (sample 541)   T. [13C-glc] Cohort3 30min
# 4943  Filename_ABC.wiff (sample 542)   U. [13C-glc] Cohort3 60min
# 4991  Filename_ABC.wiff (sample 543)  V. [13C-glc] Cohort3 120min
# 5039  Filename_ABC.wiff (sample 544)  W. [13C-glc] Cohort3 240min
# 5087  Filename_ABC.wiff (sample 546)    A. [13C-glc] Cohort1 0min
# 5135  Filename_ABC.wiff (sample 547)    B. [13C-glc] Cohort1 5min
# 5183  Filename_ABC.wiff (sample 548)   C. [13C-glc] Cohort1 15min
# 5231  Filename_ABC.wiff (sample 549)   D. [13C-glc] Cohort1 30min
# 5279  Filename_ABC.wiff (sample 550)   E. [13C-glc] Cohort1 60min
# 5327  Filename_ABC.wiff (sample 551)  F. [13C-glc] Cohort1 120min
# 5375  Filename_ABC.wiff (sample 552)  G. [13C-glc] Cohort1 240min
# 5423  Filename_ABC.wiff (sample 554)    I. [13C-glc] Cohort2 0min
# 5471  Filename_ABC.wiff (sample 555)    J. [13C-glc] Cohort2 5min
# 5519  Filename_ABC.wiff (sample 556)   K. [13C-glc] Cohort2 15min
# 5567  Filename_ABC.wiff (sample 557)   L. [13C-glc] Cohort2 30min
# 5615  Filename_ABC.wiff (sample 558)   M. [13C-glc] Cohort2 60min
# 5663  Filename_ABC.wiff (sample 559)  N. [13C-glc] Cohort2 120min
# 5711  Filename_ABC.wiff (sample 560)  O. [13C-glc] Cohort2 240min
# 5759  Filename_ABC.wiff (sample 562)    Q. [13C-glc] Cohort3 0min
# 5807  Filename_ABC.wiff (sample 563)    R. [13C-glc] Cohort3 5min
# 5855  Filename_ABC.wiff (sample 564)   S. [13C-glc] Cohort3 15min
# 5903  Filename_ABC.wiff (sample 565)   T. [13C-glc] Cohort3 30min
# 5951  Filename_ABC.wiff (sample 566)   U. [13C-glc] Cohort3 60min
# 5999  Filename_ABC.wiff (sample 567)  V. [13C-glc] Cohort3 120min
# 6047  Filename_ABC.wiff (sample 568)  W. [13C-glc] Cohort3 240min
#
#        Component Name     Intensity Modified             Name  Formula  \
# 0     Citrate 191/111  7.698357e+06    False  Citrate 191/111   C5H3O3
# 48    Citrate 191/111  8.068400e+06    False  Citrate 191/111   C5H3O3
# 96    Citrate 191/111  8.479112e+06    False  Citrate 191/111   C5H3O3
# 144   Citrate 191/111  5.234393e+06    False  Citrate 191/111   C5H3O3
# 192   Citrate 191/111  5.250939e+06    False  Citrate 191/111   C5H3O3
# 240   Citrate 191/111  4.671601e+06    False  Citrate 191/111   C5H3O3
# 288   Citrate 191/111  5.995684e+06    False  Citrate 191/111   C5H3O3
# 336   Citrate 191/111  1.495499e+07    False  Citrate 191/111   C5H3O3
# 384   Citrate 191/111  1.197312e+07    False  Citrate 191/111   C5H3O3
# 432   Citrate 191/111  8.628982e+06    False  Citrate 191/111   C5H3O3
# 480   Citrate 191/111  5.053623e+06    False  Citrate 191/111   C5H3O3
# 528   Citrate 191/111  4.469558e+06    False  Citrate 191/111   C5H3O3
# 576   Citrate 191/111  3.570443e+06    False  Citrate 191/111   C5H3O3
# 624   Citrate 191/111  3.833831e+06    False  Citrate 191/111   C5H3O3
# 672   Citrate 191/111  2.127563e+07    False  Citrate 191/111   C5H3O3
# 720   Citrate 191/111  1.655387e+07    False  Citrate 191/111   C5H3O3
# 768   Citrate 191/111  1.232305e+07    False  Citrate 191/111   C5H3O3
# 816   Citrate 191/111  8.513680e+06    False  Citrate 191/111   C5H3O3
# 5279        C6H11O6  Filename_ABC.wiff (sample 546)           0
# 5327        C6H11O6  Filename_ABC.wiff (sample 546)           0
# 5375        C6H11O6  Filename_ABC.wiff (sample 546)           0
# 5423        C6H11O6  Filename_ABC.wiff (sample 554)           0
# 5471        C6H11O6  Filename_ABC.wiff (sample 554)           0
# 5519        C6H11O6  Filename_ABC.wiff (sample 554)           0
# 5567        C6H11O6  Filename_ABC.wiff (sample 554)           0
# 5615        C6H11O6  Filename_ABC.wiff (sample 554)           0
# 5663        C6H11O6  Filename_ABC.wiff (sample 554)           0
# 5711        C6H11O6  Filename_ABC.wiff (sample 554)           0
# 5759        C6H11O6  Filename_ABC.wiff (sample 562)           0
# 5807        C6H11O6  Filename_ABC.wiff (sample 562)           0
# 5855        C6H11O6  Filename_ABC.wiff (sample 562)           0
# 5903        C6H11O6  Filename_ABC.wiff (sample 562)           0
# 5951        C6H11O6  Filename_ABC.wiff (sample 562)           0
# 5999        C6H11O6  Filename_ABC.wiff (sample 562)           0
# 6047        C6H11O6  Filename_ABC.wiff (sample 562)           0
#
#                    ...               Isotopic Tracer Number of atoms parent  \
# 0                  ...                           C13                      6
# 48                 ...                           C13                      6
# 96                 ...                           C13                      6
# 144                ...                           C13                      6
# 192                ...                           C13                      6
# 240                ...                           C13                      6
# 288                ...                           C13                      6
# 336                ...                           C13                      6
# 384                ...                           C13                      6
# 432                ...                           C13                      6
# 480                ...                           C13                      6
# 528                ...                           C13                      6
# 576                ...                           C13                      6
# 624                ...                           C13                      6
# 672                ...                           C13                      6
# 720                ...                           C13                      6
# 768                ...                           C13                      6
# 816                ...                           C13                      6
# 864                ...                           C13                      6
# 912                ...                           C13                      6
# 960                ...                           C13                      6
# 1008               ...                           C13                      6
# 1056               ...                           C13                      6
# 1104               ...                           C13                      6
# 1152               ...                           C13                      6
# 1200               ...                           C13                      6
# 1248               ...                           C13                      6
# 1296               ...                           C13                      6
# 1344               ...                           C13                      6
# 1392               ...                           C13                      6
# ...                ...                           ...                    ...
# 4655               ...                           C13                      6
# 4703               ...                           C13                      6
# 4751               ...                           C13                      6
# 4799               ...                           C13                      6
# 4847               ...                           C13                      6
# 4895               ...                           C13                      6
# 4943               ...                           C13                      6
# 4991               ...                           C13                      6
# 5039               ...                           C13                      6
# 5087               ...                           C13                      6
# 5135               ...                           C13                      6
# 5183               ...                           C13                      6
# 5231               ...                           C13                      6
# 5279               ...                           C13                      6
# 5327               ...                           C13                      6
# 5375               ...                           C13                      6
# 5423               ...                           C13                      6
# 5471               ...                           C13                      6
# 5519               ...                           C13                      6
# 5567               ...                           C13                      6
# 5615               ...                           C13                      6
# 5663               ...                           C13                      6
# 5711               ...                           C13                      6
# 5759               ...                           C13                      6
# 5807               ...                           C13                      6
# 5855               ...                           C13                      6
# 5903               ...                           C13                      6
# 5951               ...                           C13                      6
# 5999               ...                           C13                      6
# 6047               ...                           C13                      6
#
#       Parent_mass Number of labeled atoms parent  Number of atoms daughter  \
# 0             191                              0                         5
# 48            191                              0                         5
# 96            191                              0                         5
# 144           191                              0                         5
# 192           191                              0                         5
# 240           191                              0                         5
# 288           191                              0                         5
# 336           191                              0                         5
# 384           191                              0                         5
# 432           191                              0                         5
# 480           191                              0                         5
# 528           191                              0                         5
# 576           191                              0                         5
# 624           191                              0                         5
# 672           191                              0                         5
# 720           191                              0                         5
# 768           191                              0                         5
# 816           191                              0                         5
# 864           191                              0                         5
# 912           191                              0                         5
# 960           191                              0                         5
# 1008          191                              0                         5
# 1056          191                              0                         5
# 1104          191                              0                         5
# 1152          191                              0                         5
# 1200          191                              0                         5
# 1248          191                              0                         5
# 1296          191                              0                         5
# 1344          191                              0                         5
# 1392          191                              0                         5
# ...           ...                            ...                       ...
# 4655          179                              6                         6
# 4703          179                              6                         6
# 4751          179                              6                         6
# 4799          179                              6                         6
# 4847          179                              6                         6
# 4895          179                              6                         6
# 4943          179                              6                         6
# 4991          179                              6                         6
# 5039          179                              6                         6
# 5087          179                              6                         6
# 5135          179                              6                         6
# 5183          179                              6                         6
# 5231          179                              6                         6
# 5279          179                              6                         6
# 5327          179                              6                         6
# 5375          179                              6                         6
# 5423          179                              6                         6
# 5471          179                              6                         6
# 5519          179                              6                         6
# 5567          179                              6                         6
# 5615          179                              6                         6
# 5663          179                              6                         6
# 5711          179                              6                         6
# 5759          179                              6                         6
# 5807          179                              6                         6
# 5855          179                              6                         6
# 5903          179                              6                         6
# 5951          179                              6                         6
# 5999          179                              6                         6
# 6047          179                              6                         6
#
#       Daughter_mass Number of labeled atoms daughter  Unlabeled  \
# 0               111                                0       True
# 48              111                                0       True
# 96              111                                0       True
# 144             111                                0       True
# 192             111                                0       True
# 240             111                                0       True
# 288             111                                0       True
# 336             111                                0       True
# 384             111                                0       True
# 432             111                                0       True
# 480             111                                0       True
# 528             111                                0       True
# 576             111                                0       True
# 624             111                                0       True
# 672             111                                0       True
# 720             111                                0       True
# 768             111                                0       True
# 816             111                                0       True
# 864             111                                0       True
# 912             111                                0       True
# 960             111                                0       True
# 1008            111                                0       True
# 1056            111                                0       True
# 1104            111                                0       True
# 1152            111                                0       True
# 1200            111                                0       True
# 1248            111                                0       True
# 1296            111                                0       True
# 1344            111                                0       True
# 1392            111                                0       True
# ...             ...                              ...        ...
# 4655            179                                6      False
# 4703            179                                6      False
# 4751            179                                6      False
# 4799            179                                6      False
# 4847            179                                6      False
# 4895            179                                6      False
# 4943            179                                6      False
# 4991            179                                6      False
# 5039            179                                6      False
# 5087            179                                6      False
# 5135            179                                6      False
# 5183            179                                6      False
# 5231            179                                6      False
# 5279            179                                6      False
# 5327            179                                6      False
# 5375            179                                6      False
# 5423            179                                6      False
# 5471            179                                6      False
# 5519            179                                6      False
# 5567            179                                6      False
# 5615            179                                6      False
# 5663            179                                6      False
# 5711            179                                6      False
# 5759            179                                6      False
# 5807            179                                6      False
# 5855            179                                6      False
# 5903            179                                6      False
# 5951            179                                6      False
# 5999            179                                6      False
# 6047            179                                6      False
#
#       Background Corrected  Background Corrected with zero
# 0             7.698357e+06                    7.698357e+06
# 48            8.068400e+06                    8.068400e+06
# 96            8.479112e+06                    8.479112e+06
# 144           5.234393e+06                    5.234393e+06
# 192           5.250939e+06                    5.250939e+06
# 240           4.671601e+06                    4.671601e+06
# 288           5.995684e+06                    5.995684e+06
# 336           1.495499e+07                    1.495499e+07
# 384           1.197312e+07                    1.197312e+07
# 432           8.628982e+06                    8.628982e+06
# 480           5.053623e+06                    5.053623e+06
# 528           4.469558e+06                    4.469558e+06
# 576           3.570443e+06                    3.570443e+06
# 624           3.833831e+06                    3.833831e+06
# 672           2.127563e+07                    2.127563e+07
# 720           1.655387e+07                    1.655387e+07
# 768           1.232305e+07                    1.232305e+07
# 816           8.513680e+06                    8.513680e+06
# 864           6.769738e+06                    6.769738e+06
# 912           4.704536e+06                    4.704536e+06
# 960           5.136046e+06                    5.136046e+06
# 1008          9.180935e+06                    9.180935e+06
# 1056          8.690053e+06                    8.690053e+06
# 1104          7.543164e+06                    7.543164e+06
# 1152          5.510350e+06                    5.510350e+06
# 1200          4.593748e+06                    4.593748e+06
# 1248          4.377442e+06                    4.377442e+06
# 1296          4.911906e+06                    4.911906e+06
# 1344          1.162085e+07                    1.162085e+07
# 1392          8.681243e+06                    8.681243e+06
# ...                    ...                             ...
# 4655          3.403060e+03                    3.403060e+03
# 4703         -1.768366e+04                    0.000000e+00
# 4751         -7.627840e+03                    0.000000e+00
# 4799          1.049778e+04                    1.049778e+04
# 4847         -1.197760e+03                    0.000000e+00
# 4895         -1.449920e+03                    0.000000e+00
# 4943         -1.629584e+04                    0.000000e+00
# 4991         -1.134720e+04                    0.000000e+00
# 5039          1.107084e+04                    1.107084e+04
# 5087         -1.862832e+04                    0.000000e+00
# 5135         -1.106352e+04                    0.000000e+00
# 5183         -1.292320e+03                    0.000000e+00
# 5231         -1.516112e+04                    0.000000e+00
# 5279         -1.377424e+04                    0.000000e+00
# 5327         -1.702080e+04                    0.000000e+00
# 5375         -1.572848e+04                    0.000000e+00
# 5423         -1.935438e+04                    0.000000e+00
# 5471         -1.740014e+04                    0.000000e+00
# 5519         -1.002446e+04                    0.000000e+00
# 5567          7.438360e+03                    7.438360e+03
# 5615          7.500660e+03                    7.500660e+03
# 5663         -1.386990e+04                    0.000000e+00
# 5711         -1.676974e+04                    0.000000e+00
# 5759         -5.106240e+03                    0.000000e+00
# 5807          6.700781e+04                    6.700781e+04
# 5855         -3.219378e+03                    0.000000e+00
# 5903          1.739904e+04                    1.739904e+04
# 5951         -8.006080e+03                    0.000000e+00
# 5999          5.011680e+03                    5.011680e+03
# 6047         -6.177920e+03                    0.000000e+00
#
# [6048 rows x 26 columns]

# %% [markdown]
# **From Label column add information of molecular mass, isotopic mass, total number of atoms, number of labeled atoms for parent as well as isotope fragment.**

# %%
isotracer = msms_df[multiquant.ISOTRACER].unique()
intensity_col= const.BACKGROUND_WITH_ZERO

# %% [markdown]
# **Get Natural abundance value of the isotracer present in the compound(na).**

# %%
final_df[const.NA_CORRECTED_COL]=0.0
output_df= pd.DataFrame()
metab_dict={}

na= get_isotope_na(isotracer[0], isotope_dict)

# %% [markdown]
# **PARENT_NUM_ ATOMS - Total number of atoms of the isotracer element in parent formula.**
#
# **DAUGHTER_NUM_ATOMS - Total number of atoms of the isotracer element in daughter formula.**
#
# **PARENT_NUM_LABELED_ATOMS - number of labeled atoms ofisotracer element in parent formula.**
#
# **DAUGHTER_NUM_LABELED_ATOMS - number of labeled atoms ofisotracer element in daughter formula.**

# %%
final_df['A']=(1 + na * (final_df[const.PARENT_NUM_ATOMS]-final_df[const.PARENT_NUM_LABELED_ATOMS]))
final_df['B']= na * ((final_df[const.PARENT_NUM_ATOMS]-final_df[const.DAUGHTER_NUM_ATOMS]) -\
                         (final_df[const.PARENT_NUM_LABELED_ATOMS]-final_df[const.DAUGHTER_NUM_LABELED_ATOMS]-1))
final_df['C']=  na * (final_df[const.DAUGHTER_NUM_ATOMS]-final_df[const.DAUGHTER_NUM_LABELED_ATOMS]+1)

# %% [markdown]
# **Drop columns not required for processing.**

# %%
final_df.drop([const.PARENT_MASS_MOL, const.DAUGHTER_MASS_MOL, const.PARENT_NUM_ATOMS,
                const.DAUGHTER_NUM_ATOMS, const.DAUGHTER_NUM_LABELED_ATOMS, const.PARENT_NUM_LABELED_ATOMS], axis=1, inplace=True)

# %% [markdown]
# **Create metabolite : intensity dictionary of the form:**
#
#         {'SAMPLE 2_10':{
#             (191, 111): 2345.75, (192, 111):5644.847
#             }
#         }

# %%
for samp in final_df.Sample.unique():
    
    metab_df = final_df[final_df[multiquant.SAMPLE]==samp]
    frag_dict={}
    for index, row in metab_df.iterrows():
        frag_dict[(row[const.PARENT_MASS_ISO],row[const.DAUGHTER_MASS_ISO])]=row[intensity_col]
    
    metab_dict[samp]= frag_dict

# %% [markdown]
# **In each sample correct the intensities of daughter fragment one by one using the intensity of M+0 isotopolgue.**

# %%
for samp in final_df.Sample.unique():
    metab_df = final_df[final_df[multiquant.SAMPLE]==samp]
    frag= metab_dict[samp]  
     
    for index, row in metab_df.iterrows():
        m_n= row[const.DAUGHTER_MASS_ISO]
        m_1_n= row[const.PARENT_MASS_ISO]-1
        m_n_1= row[const.DAUGHTER_MASS_ISO]-1
        intensity_m_n= row[intensity_col]
        try:
            intensity_m_1_n= frag[m_1_n, m_n]
        except KeyError:
            intensity_m_1_n=0
        try:
            intensity_m_1_n_1= frag[m_1_n, m_n_1]
        except KeyError:
            intensity_m_1_n_1= 0
        
        corrected= intensity_m_n * row['A']  - intensity_m_1_n * row['B'] -\
                                                intensity_m_1_n_1 * row['C']
        metab_df.set_value(index=index, col=const.NA_CORRECTED_COL, value= corrected)

    output_df=output_df.append(metab_df)

# %% [markdown]
# **Filter the output dataframe to extract the required columns.**

# %%
output_df= output_df.filter(REQUIRED_COL)
output_df = replace_negatives_in_column(output_df,const.NA_CORRECTED_WITH_ZERO, const.NA_CORRECTED_COL)
print output_df

# %% [markdown]
# **Calculate Fractional Enrichment**

# %%
fractional_enriched_df = fractional_enrichment(output_df)
print fractional_enriched_df

# %%
df= pd.merge(output_df, fractional_enriched_df, on=['Label', 'Sample', 'Name', 'Formula'])
print df
